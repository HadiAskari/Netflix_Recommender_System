# %%
# Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
print(torch.__version__)
import pkg_resources
pkg_resources.require("torch==1.11.0+cu113")
print(torch.__version__)
print(torch.version)
# Out:
# 1.11.0
# 1.11.0
# <module 'torch.version' from '/home/haskari/.conda/envs/ML/lib/python3.9/site-packages/torch/version.py'>

# %%
cd /content/drive/MyDrive/Netflix_Assignment
# Out:
# /content/drive/MyDrive/Netflix_Assignment

# %%
# !ls
# Out:
# clusters.npy  sdae_netflix_weights.pt  train.csv     validation.csv
# IDEC.ipynb    SVDforDeep.ipynb	       training.csv
# SDAE.ipynb    test.csv		       users.npy

# %%
# !ls

# %%
d=np.load("users.npy")
print(d.shape)
# Out:
# (5903, 15895)

# %%
import os
import os.path
import errno
import numpy as np
import gzip
import torch
import pickle
import torch.utils.data as data
import codecs
import urllib
class Netflix(data.Dataset):
    def __init__(self, root, train=True, transform=None, target_transform=None, download=False):
        self.root = os.path.expanduser(root)
        self.transform = transform
        self.target_transform = target_transform
        self.train = train  # training set or test set
        self.use_cuda = torch.cuda.is_available()
        self.training_file = "users.npy" # your data for clustering (e.g., user-predictions matrix, user-embedding learned from SVD ...)
        self.label_file = "clusters.npy" # clustering labels (not applicable for our assignment, I used the k-means labels for svd_pu file)
        if download:
            self.download()
        train = np.load(self.training_file)
        from sklearn.preprocessing import StandardScaler
        scaler = StandardScaler()
        label = np.load(self.label_file)
        train = scaler.fit_transform(train)
        if self.train:
            self.train_data, self.train_labels = torch.tensor(train, dtype=torch.float32), torch.tensor(label, dtype=torch.int)
            if self.use_cuda:
                self.train_data = self.train_data.cuda()
                self.train_labels = self.train_labels.cuda()
        else:
            self.test_data, self.test_labels = torch.tensor(train, dtype=torch.float32), torch.tensor(label, dtype=torch.int)
            if self.use_cuda:
                self.test_data = self.test_data.cuda()
                self.test_labels = self.test_labels.cuda()
    def __getitem__(self, index):
        if self.train:
            img, target = self.train_data[index], self.train_labels[index]
        else:
            img, target = self.test_data[index], self.test_labels[index]

        return img, target

    def __len__(self):
        if self.train:
            return len(self.train_data)
        else:
            return len(self.test_data)

# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import math

class Dataset(data.Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        self.data = data
        self.labels = labels
        if torch.cuda.is_available():
            self.data = self.data.cuda()
            self.labels = self.labels.cuda()

    def __getitem__(self, index):
        img, target = self.data[index], self.labels[index]
        # img = Image.fromarray(img)
        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)

        return img, target

    def __len__(self):
        return len(self.data)


def masking_noise(data, frac):
    """
    data: Tensor
    frac: fraction of unit to be masked out
    """
    data_noise = data.clone()
    rand = torch.rand(data.size())
    data_noise[rand<frac] = 0
    return data_noise

class MSELoss(nn.Module):
    def __init__(self):
        super(self.__class__, self).__init__()

    def forward(self, input, target):
        return 0.5 * torch.mean((input-target)**2)

class BCELoss(nn.Module):
    def __init__(self):
        super(self.__class__, self).__init__()

    def forward(self, input, target):
        return -torch.mean(torch.sum(target*torch.log(torch.clamp(input, min=1e-10))+
            (1-target)*torch.log(torch.clamp(1-input, min=1e-10)), 1))
        

def adjust_learning_rate(init_lr, optimizer, epoch):
    lr = init_lr * (0.1 ** (epoch//100))
    toprint = True
    for param_group in optimizer.param_groups:
        if param_group["lr"]!=lr:
            param_group["lr"] = lr
            if toprint:
                print("Switching to learning rate %f" % lr)
                toprint = False

class DenoisingAutoencoder(nn.Module):
    def __init__(self, in_features, out_features, activation="relu", 
        dropout=0.2, tied=False):
        super(self.__class__, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.Tensor(out_features, in_features))
        if tied:
            self.deweight = self.weight.t()
        else:
            self.deweight = Parameter(torch.Tensor(in_features, out_features))
        self.bias = Parameter(torch.Tensor(out_features))
        self.vbias = Parameter(torch.Tensor(in_features))
        
        if activation=="relu":
            self.enc_act_func = nn.ReLU()
        elif activation=="sigmoid":
            self.enc_act_func = nn.Sigmoid()
        elif activation=="none":
            self.enc_act_func = None
        self.dropout = nn.Dropout(p=dropout)

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 0.01
        self.weight.data.uniform_(-stdv, stdv)
        self.bias.data.uniform_(-stdv, stdv)
        stdv = 0.01
        self.deweight.data.uniform_(-stdv, stdv)
        self.vbias.data.uniform_(-stdv, stdv)

    def forward(self, x):
        if self.enc_act_func is not None:
            return self.dropout(self.enc_act_func(F.linear(x, self.weight, self.bias)))
        else:
            return self.dropout(F.linear(x, self.weight, self.bias))

    def encode(self, x, train=True):
        if train:
            self.dropout.train()
        else:
            self.dropout.eval()
        if self.enc_act_func is not None:
            return self.dropout(self.enc_act_func(F.linear(x, self.weight, self.bias)))
        else:
            return self.dropout(F.linear(x, self.weight, self.bias))

    def encodeBatch(self, dataloader):
        use_cuda = torch.cuda.is_available()
        encoded = []
        for batch_idx, (inputs, _) in enumerate(dataloader):
            inputs = inputs.view(inputs.size(0), -1).float()
            if use_cuda:
                inputs = inputs.cuda()
            inputs = Variable(inputs)
            hidden = self.encode(inputs, train=False)
            encoded.append(hidden.data.cpu())

        encoded = torch.cat(encoded, dim=0)
        return encoded

    def decode(self, x, binary=False):
        if not binary:
            return F.linear(x, self.deweight, self.vbias)
        else:
            return F.sigmoid(F.linear(x, self.deweight, self.vbias))

    def fit(self, trainloader, validloader, lr=0.001, batch_size=128, num_epochs=10, corrupt=0.3,
        loss_type="mse"):
        """
        data_x: FloatTensor
        valid_x: FloatTensor
        """
        use_cuda = torch.cuda.is_available()
        if use_cuda:
            self.cuda()
        print("=====Denoising Autoencoding layer=======")
        # optimizer = optim.Adam(filter(lambda p: p.requires_grad, self.parameters()), lr=lr)
        optimizer = optim.SGD(filter(lambda p: p.requires_grad, self.parameters()), lr=lr, momentum=0.9)
        if loss_type=="mse":
            criterion = MSELoss()
        elif loss_type=="cross-entropy":
            criterion = BCELoss()

        # validate
        total_loss = 0.0
        total_num = 0
        for batch_idx, (inputs, _) in enumerate(validloader):
            # inputs = inputs.view(inputs.size(0), -1).float()
            # if use_cuda:
            #     inputs = inputs.cuda()
            inputs = Variable(inputs)
            hidden = self.encode(inputs)
            if loss_type=="cross-entropy":
                outputs = self.decode(hidden, binary=True)
            else:
                outputs = self.decode(hidden)

            valid_recon_loss = criterion(outputs, inputs)
            total_loss += valid_recon_loss.data * len(inputs)
            total_num += inputs.size()[0]

        valid_loss = total_loss / total_num
        print("#Epoch 0: Valid Reconstruct Loss: %.4f" % (valid_loss))

        self.train()
        for epoch in range(num_epochs):
            # train 1 epoch
            train_loss = 0.0
            adjust_learning_rate(lr, optimizer, epoch)
            for batch_idx, (inputs, _) in enumerate(trainloader):
                # inputs = inputs.view(inputs.size(0), -1).float()
                inputs_corr = masking_noise(inputs, corrupt)
                # if use_cuda:
                #     inputs = inputs.cuda()
                #     inputs_corr = inputs_corr.cuda()
                optimizer.zero_grad()
                inputs = Variable(inputs)
                inputs_corr = Variable(inputs_corr)

                hidden = self.encode(inputs_corr)
                if loss_type=="cross-entropy":
                    outputs = self.decode(hidden, binary=True)
                else:
                    outputs = self.decode(hidden)
                recon_loss = criterion(outputs, inputs)
                train_loss += recon_loss.data*len(inputs)
                recon_loss.backward()
                optimizer.step()

            # validate
            valid_loss = 0.0
            for batch_idx, (inputs, _) in enumerate(validloader):
                # inputs = inputs.view(inputs.size(0), -1).float()
                # if use_cuda:
                #     inputs = inputs.cuda()
                inputs = Variable(inputs)
                hidden = self.encode(inputs, train=False)
                if loss_type=="cross-entropy":
                    outputs = self.decode(hidden, binary=True)
                else:
                    outputs = self.decode(hidden)

                valid_recon_loss = criterion(outputs, inputs)
                valid_loss += valid_recon_loss.data * len(inputs)

            print("#Epoch %3d: Reconstruct Loss: %.4f, Valid Reconstruct Loss: %.4f" % (
                epoch+1, train_loss / len(trainloader.dataset), valid_loss / len(validloader.dataset)))

    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )

# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import math

def buildNetwork(layers, activation="relu", dropout=0):
    net = []
    for i in range(1, len(layers)):
        net.append(nn.Linear(layers[i-1], layers[i]))
        if activation=="relu":
            net.append(nn.ReLU())
        elif activation=="sigmoid":
            net.append(nn.Sigmoid())
        if dropout > 0:
            net.append(nn.Dropout(dropout))
    return nn.Sequential(*net)

def adjust_learning_rate(init_lr, optimizer, epoch):
    lr = init_lr * (0.1 ** (epoch//100))
    toprint = True
    for param_group in optimizer.param_groups:
        if param_group["lr"]!=lr:
            param_group["lr"] = lr
            if toprint:
                print("Switching to learning rate %f" % lr)
                toprint = False

class StackedDAE(nn.Module):
    def __init__(self, input_dim=784, z_dim=10, binary=True,
        encodeLayer=[400], decodeLayer=[400], activation="relu", 
        dropout=0.8, tied=False):
        super(self.__class__, self).__init__()
        self.z_dim = z_dim
        self.layers = [input_dim] + encodeLayer + [z_dim]
        self.activation = activation
        self.dropout = dropout
        self.encoder = buildNetwork([input_dim] + encodeLayer, activation=activation, dropout=dropout)
        self.decoder = buildNetwork([z_dim] + decodeLayer, activation=activation, dropout=dropout)
        self._enc_mu = nn.Linear(encodeLayer[-1], z_dim)
        
        self._dec = nn.Linear(decodeLayer[-1], input_dim)
        self._dec_act = None
        if binary:
            self._dec_act = nn.Sigmoid()

    def decode(self, z):
        h = self.decoder(z)
        x = self._dec(h)
        if self._dec_act is not None:
            x = self._dec_act(x)
        return x

    def loss_function(self, recon_x, x):
        loss = -torch.mean(torch.sum(x*torch.log(torch.clamp(recon_x, min=1e-10))+
            (1-x)*torch.log(torch.clamp(1-recon_x, min=1e-10)), 1))

        return loss

    def forward(self, x):
        h = self.encoder(x)
        z = self._enc_mu(h)

        return z, self.decode(z)

    def save_model(self, path):
        torch.save(self.state_dict(), path)

    def load_model(self, path):
        pretrained_dict = torch.load(path, map_location=lambda storage, loc: storage)
        model_dict = self.state_dict()
        pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict}
        model_dict.update(pretrained_dict) 
        self.load_state_dict(model_dict)

    def pretrain(self, trainloader, validloader, lr=0.001, batch_size=128, num_epochs=10, corrupt=0.2, loss_type="cross-entropy"):
        trloader = trainloader
        valoader = validloader
        daeLayers = []
        for l in range(1, len(self.layers)):
            infeatures = self.layers[l-1]
            outfeatures = self.layers[l]
            if l!= len(self.layers)-1:
                dae = DenoisingAutoencoder(infeatures, outfeatures, activation=self.activation, dropout=corrupt)
            else:
                dae = DenoisingAutoencoder(infeatures, outfeatures, activation="none", dropout=0)
            print(dae)
            if l==1:
                dae.fit(trloader, valoader, lr=lr, batch_size=batch_size, num_epochs=num_epochs, corrupt=corrupt, loss_type=loss_type)
            else:
                if self.activation=="sigmoid":
                    dae.fit(trloader, valoader, lr=lr, batch_size=batch_size, num_epochs=num_epochs, corrupt=corrupt, loss_type="cross-entropy")
                else:
                    dae.fit(trloader, valoader, lr=lr, batch_size=batch_size, num_epochs=num_epochs, corrupt=corrupt, loss_type="mse")
            data_x = dae.encodeBatch(trloader)
            valid_x = dae.encodeBatch(valoader)
            trainset = Dataset(data_x, data_x)
            trloader = torch.utils.data.DataLoader(
                trainset, batch_size=batch_size, shuffle=True, num_workers=0)
            validset = Dataset(valid_x, valid_x)
            valoader = torch.utils.data.DataLoader(
                validset, batch_size=1000, shuffle=False, num_workers=0)
            daeLayers.append(dae)

        self.copyParam(daeLayers)

    def copyParam(self, daeLayers):
        if self.dropout==0:
            every = 2
        else:
            every = 3
        # input layer
        # copy encoder weight
        self.encoder[0].weight.data.copy_(daeLayers[0].weight.data)
        self.encoder[0].bias.data.copy_(daeLayers[0].bias.data)
        self._dec.weight.data.copy_(daeLayers[0].deweight.data)
        self._dec.bias.data.copy_(daeLayers[0].vbias.data)

        for l in range(1, len(self.layers)-2):
            # copy encoder weight
            self.encoder[l*every].weight.data.copy_(daeLayers[l].weight.data)
            self.encoder[l*every].bias.data.copy_(daeLayers[l].bias.data)

            # copy decoder weight
            self.decoder[-(l-1)*every-2].weight.data.copy_(daeLayers[l].deweight.data)
            self.decoder[-(l-1)*every-2].bias.data.copy_(daeLayers[l].vbias.data)

        # z layer
        self._enc_mu.weight.data.copy_(daeLayers[-1].weight.data)
        self._enc_mu.bias.data.copy_(daeLayers[-1].bias.data)
        self.decoder[0].weight.data.copy_(daeLayers[-1].deweight.data)
        self.decoder[0].bias.data.copy_(daeLayers[-1].vbias.data)

    def fit(self, trainloader, validloader, lr=0.001, num_epochs=10, corrupt=0.3,
        loss_type="mse"):
        """
        data_x: FloatTensor
        valid_x: FloatTensor
        """
        use_cuda = torch.cuda.is_available()
        if use_cuda:
            self.cuda()
        print("=====Stacked Denoising Autoencoding Layer=======")
        # optimizer = optim.Adam(filter(lambda p: p.requires_grad, self.parameters()), lr=lr)
        optimizer = optim.SGD(filter(lambda p: p.requires_grad, self.parameters()), lr=lr, momentum=0.9)
        if loss_type=="mse":
            criterion = MSELoss()
        elif loss_type=="cross-entropy":
            criterion = BCELoss()

        # validate
        total_loss = 0.0
        total_num = 0
        for batch_idx, (inputs, _) in enumerate(validloader):
            inputs = inputs.view(inputs.size(0), -1).float()
            if use_cuda:
                inputs = inputs.cuda()
            inputs = Variable(inputs)
            z, outputs = self.forward(inputs)

            valid_recon_loss = criterion(outputs, inputs)
            total_loss += valid_recon_loss.data * len(inputs)
            total_num += inputs.size()[0]

        valid_loss = total_loss / total_num
        print("#Epoch 0: Valid Reconstruct Loss: %.4f" % (valid_loss))
        self.train()
        for epoch in range(num_epochs):
            # train 1 epoch
            adjust_learning_rate(lr, optimizer, epoch)
            train_loss = 0.0
            for batch_idx, (inputs, _) in enumerate(trainloader):
                inputs = inputs.view(inputs.size(0), -1).float()
                inputs_corr = masking_noise(inputs, corrupt)
                if use_cuda:
                    inputs = inputs.cuda()
                    inputs_corr = inputs_corr.cuda()
                optimizer.zero_grad()
                inputs = Variable(inputs)
                inputs_corr = Variable(inputs_corr)

                z, outputs = self.forward(inputs_corr)
                recon_loss = criterion(outputs, inputs)
                train_loss += recon_loss.data*len(inputs)
                recon_loss.backward()
                optimizer.step()

            # validate
            valid_loss = 0.0
            for batch_idx, (inputs, _) in enumerate(validloader):
                inputs = inputs.view(inputs.size(0), -1).float()
                if use_cuda:
                    inputs = inputs.cuda()
                inputs = Variable(inputs)
                z, outputs = self.forward(inputs)

                valid_recon_loss = criterion(outputs, inputs)
                valid_loss += valid_recon_loss.data * len(inputs)

            print("#Epoch %3d: Reconstruct Loss: %.4f, Valid Reconstruct Loss: %.4f" % (
                epoch+1, train_loss / len(trainloader.dataset), valid_loss / len(validloader.dataset)))

# %%
import sys
sys.path.append("..")
import torch.utils.data
import argparse


if __name__ == "__main__":
    # Load data for pre-training
    train_loader = torch.utils.data.DataLoader(
        Netflix('', train=True),
        batch_size=256, shuffle=True, num_workers=0)
    test_loader = torch.utils.data.DataLoader(
        Netflix('', train=False),
        batch_size=256, shuffle=False, num_workers=0)

    sdae = StackedDAE(input_dim=15895, z_dim=20, binary=False,
                      encodeLayer=[500, 500, 2000], decodeLayer=[2000, 500, 500], activation="relu",
                      dropout=0)
    
    # Print the pre-train model structure
    print(sdae)
    sdae.pretrain(train_loader, test_loader, lr=0.1, batch_size=256,
                  num_epochs=300, corrupt=0.2, loss_type="mse")
    
    # Train the stacked denoising autoencoder
    sdae.fit(train_loader, test_loader, lr=0.1, num_epochs=500, corrupt=0.2, loss_type="mse")
    
    # Save the weights as pre-trained model for IDEC/DEC/DCC
    sdae.save_model("sdae_netflix_weights.pt")
# Out:
# StackedDAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=15895, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=500, out_features=500, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=500, out_features=2000, bias=True)
#     (5): ReLU()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=20, out_features=2000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=2000, out_features=500, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=500, out_features=500, bias=True)
#     (5): ReLU()
#   )
#   (_enc_mu): Linear(in_features=2000, out_features=20, bias=True)
#   (_dec): Linear(in_features=500, out_features=15895, bias=True)
# )
# DenoisingAutoencoder(
#   in_features=15895, out_features=500, bias=True
#   (enc_act_func): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# =====Denoising Autoencoding layer=======
# #Epoch 0: Valid Reconstruct Loss: 0.5030
# #Epoch   1: Reconstruct Loss: 0.4722, Valid Reconstruct Loss: 0.3077
# #Epoch   2: Reconstruct Loss: 0.2147, Valid Reconstruct Loss: 0.1618
# #Epoch   3: Reconstruct Loss: 0.1509, Valid Reconstruct Loss: 0.1512
# #Epoch   4: Reconstruct Loss: 0.1454, Valid Reconstruct Loss: 0.1479
# #Epoch   5: Reconstruct Loss: 0.1427, Valid Reconstruct Loss: 0.1506
# #Epoch   6: Reconstruct Loss: 0.1401, Valid Reconstruct Loss: 0.1425
# #Epoch   7: Reconstruct Loss: 0.1373, Valid Reconstruct Loss: 0.1410
# #Epoch   8: Reconstruct Loss: 0.1337, Valid Reconstruct Loss: 0.1398
# #Epoch   9: Reconstruct Loss: 0.1295, Valid Reconstruct Loss: 0.1367
# #Epoch  10: Reconstruct Loss: 0.1257, Valid Reconstruct Loss: 0.1321
# #Epoch  11: Reconstruct Loss: 0.1229, Valid Reconstruct Loss: 0.1313
# #Epoch  12: Reconstruct Loss: 0.1212, Valid Reconstruct Loss: 0.1292
# #Epoch  13: Reconstruct Loss: 0.1201, Valid Reconstruct Loss: 0.1297
# #Epoch  14: Reconstruct Loss: 0.1191, Valid Reconstruct Loss: 0.1299
# #Epoch  15: Reconstruct Loss: 0.1185, Valid Reconstruct Loss: 0.1255
# #Epoch  16: Reconstruct Loss: 0.1178, Valid Reconstruct Loss: 0.1275
# #Epoch  17: Reconstruct Loss: 0.1173, Valid Reconstruct Loss: 0.1324
# #Epoch  18: Reconstruct Loss: 0.1167, Valid Reconstruct Loss: 0.1265
# #Epoch  19: Reconstruct Loss: 0.1162, Valid Reconstruct Loss: 0.1261
# #Epoch  20: Reconstruct Loss: 0.1159, Valid Reconstruct Loss: 0.1286
# #Epoch  21: Reconstruct Loss: 0.1155, Valid Reconstruct Loss: 0.1292
# #Epoch  22: Reconstruct Loss: 0.1150, Valid Reconstruct Loss: 0.1292
# #Epoch  23: Reconstruct Loss: 0.1145, Valid Reconstruct Loss: 0.1262
# #Epoch  24: Reconstruct Loss: 0.1142, Valid Reconstruct Loss: 0.1305
# #Epoch  25: Reconstruct Loss: 0.1136, Valid Reconstruct Loss: 0.1285
# #Epoch  26: Reconstruct Loss: 0.1133, Valid Reconstruct Loss: 0.1268
# #Epoch  27: Reconstruct Loss: 0.1126, Valid Reconstruct Loss: 0.1214
# #Epoch  28: Reconstruct Loss: 0.1121, Valid Reconstruct Loss: 0.1345
# #Epoch  29: Reconstruct Loss: 0.1133, Valid Reconstruct Loss: 0.1334
# #Epoch  30: Reconstruct Loss: 0.1115, Valid Reconstruct Loss: 0.1188
# #Epoch  31: Reconstruct Loss: 0.1107, Valid Reconstruct Loss: 0.1234
# #Epoch  32: Reconstruct Loss: 0.1099, Valid Reconstruct Loss: 0.1213
# #Epoch  33: Reconstruct Loss: 0.1095, Valid Reconstruct Loss: 0.1237
# #Epoch  34: Reconstruct Loss: 0.1091, Valid Reconstruct Loss: 0.1262
# #Epoch  35: Reconstruct Loss: 0.1085, Valid Reconstruct Loss: 0.1215
# #Epoch  36: Reconstruct Loss: 0.1080, Valid Reconstruct Loss: 0.1185
# #Epoch  37: Reconstruct Loss: 0.1075, Valid Reconstruct Loss: 0.1234
# #Epoch  38: Reconstruct Loss: 0.1069, Valid Reconstruct Loss: 0.1187
# #Epoch  39: Reconstruct Loss: 0.1066, Valid Reconstruct Loss: 0.1251
# #Epoch  40: Reconstruct Loss: 0.1062, Valid Reconstruct Loss: 0.1190
# #Epoch  41: Reconstruct Loss: 0.1056, Valid Reconstruct Loss: 0.1131
# #Epoch  42: Reconstruct Loss: 0.1055, Valid Reconstruct Loss: 0.1248
# #Epoch  43: Reconstruct Loss: 0.1050, Valid Reconstruct Loss: 0.1184
# #Epoch  44: Reconstruct Loss: 0.1046, Valid Reconstruct Loss: 0.1186
# #Epoch  45: Reconstruct Loss: 0.1042, Valid Reconstruct Loss: 0.1192
# #Epoch  46: Reconstruct Loss: 0.1039, Valid Reconstruct Loss: 0.1185
# #Epoch  47: Reconstruct Loss: 0.1033, Valid Reconstruct Loss: 0.1188
# #Epoch  48: Reconstruct Loss: 0.1030, Valid Reconstruct Loss: 0.1175
# #Epoch  49: Reconstruct Loss: 0.1029, Valid Reconstruct Loss: 0.1101
# #Epoch  50: Reconstruct Loss: 0.1026, Valid Reconstruct Loss: 0.1245
# #Epoch  51: Reconstruct Loss: 0.1025, Valid Reconstruct Loss: 0.1170
# #Epoch  52: Reconstruct Loss: 0.1017, Valid Reconstruct Loss: 0.1207
# #Epoch  53: Reconstruct Loss: 0.1015, Valid Reconstruct Loss: 0.1109
# #Epoch  54: Reconstruct Loss: 0.1012, Valid Reconstruct Loss: 0.1231
# #Epoch  55: Reconstruct Loss: 0.1008, Valid Reconstruct Loss: 0.1130
# #Epoch  56: Reconstruct Loss: 0.1005, Valid Reconstruct Loss: 0.1109
# #Epoch  57: Reconstruct Loss: 0.1004, Valid Reconstruct Loss: 0.1192
# #Epoch  58: Reconstruct Loss: 0.0998, Valid Reconstruct Loss: 0.1161
# #Epoch  59: Reconstruct Loss: 0.0995, Valid Reconstruct Loss: 0.1124
# #Epoch  60: Reconstruct Loss: 0.0992, Valid Reconstruct Loss: 0.1122
# #Epoch  61: Reconstruct Loss: 0.0990, Valid Reconstruct Loss: 0.1136
# #Epoch  62: Reconstruct Loss: 0.0984, Valid Reconstruct Loss: 0.1171
# #Epoch  63: Reconstruct Loss: 0.0981, Valid Reconstruct Loss: 0.1167
# #Epoch  64: Reconstruct Loss: 0.0976, Valid Reconstruct Loss: 0.1150
# #Epoch  65: Reconstruct Loss: 0.0972, Valid Reconstruct Loss: 0.1169
# #Epoch  66: Reconstruct Loss: 0.0969, Valid Reconstruct Loss: 0.1135
# #Epoch  67: Reconstruct Loss: 0.0966, Valid Reconstruct Loss: 0.1101
# #Epoch  68: Reconstruct Loss: 0.0963, Valid Reconstruct Loss: 0.1154
# #Epoch  69: Reconstruct Loss: 0.0957, Valid Reconstruct Loss: 0.1090
# #Epoch  70: Reconstruct Loss: 0.0954, Valid Reconstruct Loss: 0.1096
# #Epoch  71: Reconstruct Loss: 0.0950, Valid Reconstruct Loss: 0.1090
# #Epoch  72: Reconstruct Loss: 0.0951, Valid Reconstruct Loss: 0.1104
# #Epoch  73: Reconstruct Loss: 0.0946, Valid Reconstruct Loss: 0.1040
# #Epoch  74: Reconstruct Loss: 0.0941, Valid Reconstruct Loss: 0.1092
# #Epoch  75: Reconstruct Loss: 0.0936, Valid Reconstruct Loss: 0.1056
# #Epoch  76: Reconstruct Loss: 0.0933, Valid Reconstruct Loss: 0.1039
# #Epoch  77: Reconstruct Loss: 0.0929, Valid Reconstruct Loss: 0.1007
# #Epoch  78: Reconstruct Loss: 0.0926, Valid Reconstruct Loss: 0.1067
# #Epoch  79: Reconstruct Loss: 0.0921, Valid Reconstruct Loss: 0.1070
# #Epoch  80: Reconstruct Loss: 0.0917, Valid Reconstruct Loss: 0.0998
# #Epoch  81: Reconstruct Loss: 0.0916, Valid Reconstruct Loss: 0.1041
# #Epoch  82: Reconstruct Loss: 0.0912, Valid Reconstruct Loss: 0.1008
# #Epoch  83: Reconstruct Loss: 0.0906, Valid Reconstruct Loss: 0.1006
# #Epoch  84: Reconstruct Loss: 0.0905, Valid Reconstruct Loss: 0.1002
# #Epoch  85: Reconstruct Loss: 0.0901, Valid Reconstruct Loss: 0.1184
# #Epoch  86: Reconstruct Loss: 0.0902, Valid Reconstruct Loss: 0.0989
# #Epoch  87: Reconstruct Loss: 0.0890, Valid Reconstruct Loss: 0.1050
# #Epoch  88: Reconstruct Loss: 0.0885, Valid Reconstruct Loss: 0.1018
# #Epoch  89: Reconstruct Loss: 0.0882, Valid Reconstruct Loss: 0.0999
# #Epoch  90: Reconstruct Loss: 0.0879, Valid Reconstruct Loss: 0.1072
# #Epoch  91: Reconstruct Loss: 0.0877, Valid Reconstruct Loss: 0.0918
# #Epoch  92: Reconstruct Loss: 0.0891, Valid Reconstruct Loss: 0.0934
# #Epoch  93: Reconstruct Loss: 0.0881, Valid Reconstruct Loss: 0.1017
# #Epoch  94: Reconstruct Loss: 0.0864, Valid Reconstruct Loss: 0.1012
# #Epoch  95: Reconstruct Loss: 0.0857, Valid Reconstruct Loss: 0.0968
# #Epoch  96: Reconstruct Loss: 0.0855, Valid Reconstruct Loss: 0.0992
# #Epoch  97: Reconstruct Loss: 0.0851, Valid Reconstruct Loss: 0.1056
# #Epoch  98: Reconstruct Loss: 0.0848, Valid Reconstruct Loss: 0.1088
# #Epoch  99: Reconstruct Loss: 0.0846, Valid Reconstruct Loss: 0.0997
# #Epoch 100: Reconstruct Loss: 0.0836, Valid Reconstruct Loss: 0.1061
# Switching to learning rate 0.010000
# #Epoch 101: Reconstruct Loss: 0.0835, Valid Reconstruct Loss: 0.0966
# #Epoch 102: Reconstruct Loss: 0.0834, Valid Reconstruct Loss: 0.0987
# #Epoch 103: Reconstruct Loss: 0.0832, Valid Reconstruct Loss: 0.0974
# #Epoch 104: Reconstruct Loss: 0.0831, Valid Reconstruct Loss: 0.0977
# #Epoch 105: Reconstruct Loss: 0.0830, Valid Reconstruct Loss: 0.0957
# #Epoch 106: Reconstruct Loss: 0.0831, Valid Reconstruct Loss: 0.0966
# #Epoch 107: Reconstruct Loss: 0.0831, Valid Reconstruct Loss: 0.0967
# #Epoch 108: Reconstruct Loss: 0.0831, Valid Reconstruct Loss: 0.0973
# #Epoch 109: Reconstruct Loss: 0.0829, Valid Reconstruct Loss: 0.0976
# #Epoch 110: Reconstruct Loss: 0.0829, Valid Reconstruct Loss: 0.0970
# #Epoch 111: Reconstruct Loss: 0.0829, Valid Reconstruct Loss: 0.0971
# #Epoch 112: Reconstruct Loss: 0.0828, Valid Reconstruct Loss: 0.0970
# #Epoch 113: Reconstruct Loss: 0.0827, Valid Reconstruct Loss: 0.0969
# #Epoch 114: Reconstruct Loss: 0.0827, Valid Reconstruct Loss: 0.0986
# #Epoch 115: Reconstruct Loss: 0.0827, Valid Reconstruct Loss: 0.0950
# #Epoch 116: Reconstruct Loss: 0.0826, Valid Reconstruct Loss: 0.0958
# #Epoch 117: Reconstruct Loss: 0.0827, Valid Reconstruct Loss: 0.0978
# #Epoch 118: Reconstruct Loss: 0.0825, Valid Reconstruct Loss: 0.0977
# #Epoch 119: Reconstruct Loss: 0.0825, Valid Reconstruct Loss: 0.0948
# #Epoch 120: Reconstruct Loss: 0.0825, Valid Reconstruct Loss: 0.0940
# #Epoch 121: Reconstruct Loss: 0.0824, Valid Reconstruct Loss: 0.0946
# #Epoch 122: Reconstruct Loss: 0.0824, Valid Reconstruct Loss: 0.0961
# #Epoch 123: Reconstruct Loss: 0.0823, Valid Reconstruct Loss: 0.0963
# #Epoch 124: Reconstruct Loss: 0.0822, Valid Reconstruct Loss: 0.0946
# #Epoch 125: Reconstruct Loss: 0.0823, Valid Reconstruct Loss: 0.0946
# #Epoch 126: Reconstruct Loss: 0.0823, Valid Reconstruct Loss: 0.0970
# #Epoch 127: Reconstruct Loss: 0.0821, Valid Reconstruct Loss: 0.0967
# #Epoch 128: Reconstruct Loss: 0.0821, Valid Reconstruct Loss: 0.0956
# #Epoch 129: Reconstruct Loss: 0.0820, Valid Reconstruct Loss: 0.0955
# #Epoch 130: Reconstruct Loss: 0.0821, Valid Reconstruct Loss: 0.0960
# #Epoch 131: Reconstruct Loss: 0.0820, Valid Reconstruct Loss: 0.0951
# #Epoch 132: Reconstruct Loss: 0.0819, Valid Reconstruct Loss: 0.0947
# #Epoch 133: Reconstruct Loss: 0.0819, Valid Reconstruct Loss: 0.0944
# #Epoch 134: Reconstruct Loss: 0.0818, Valid Reconstruct Loss: 0.0937
# #Epoch 135: Reconstruct Loss: 0.0817, Valid Reconstruct Loss: 0.0955
# #Epoch 136: Reconstruct Loss: 0.0818, Valid Reconstruct Loss: 0.0948
# #Epoch 137: Reconstruct Loss: 0.0817, Valid Reconstruct Loss: 0.0962
# #Epoch 138: Reconstruct Loss: 0.0816, Valid Reconstruct Loss: 0.0945
# #Epoch 139: Reconstruct Loss: 0.0816, Valid Reconstruct Loss: 0.0954
# #Epoch 140: Reconstruct Loss: 0.0815, Valid Reconstruct Loss: 0.0968
# #Epoch 141: Reconstruct Loss: 0.0815, Valid Reconstruct Loss: 0.0960
# #Epoch 142: Reconstruct Loss: 0.0815, Valid Reconstruct Loss: 0.0954
# #Epoch 143: Reconstruct Loss: 0.0814, Valid Reconstruct Loss: 0.0960
# #Epoch 144: Reconstruct Loss: 0.0814, Valid Reconstruct Loss: 0.0946
# #Epoch 145: Reconstruct Loss: 0.0813, Valid Reconstruct Loss: 0.0922
# #Epoch 146: Reconstruct Loss: 0.0812, Valid Reconstruct Loss: 0.0952
# #Epoch 147: Reconstruct Loss: 0.0813, Valid Reconstruct Loss: 0.0949
# #Epoch 148: Reconstruct Loss: 0.0811, Valid Reconstruct Loss: 0.0946
# #Epoch 149: Reconstruct Loss: 0.0811, Valid Reconstruct Loss: 0.0958
# #Epoch 150: Reconstruct Loss: 0.0811, Valid Reconstruct Loss: 0.0933
# #Epoch 151: Reconstruct Loss: 0.0811, Valid Reconstruct Loss: 0.0945
# #Epoch 152: Reconstruct Loss: 0.0810, Valid Reconstruct Loss: 0.0935
# #Epoch 153: Reconstruct Loss: 0.0810, Valid Reconstruct Loss: 0.0930
# #Epoch 154: Reconstruct Loss: 0.0809, Valid Reconstruct Loss: 0.0953
# #Epoch 155: Reconstruct Loss: 0.0808, Valid Reconstruct Loss: 0.0944
# #Epoch 156: Reconstruct Loss: 0.0809, Valid Reconstruct Loss: 0.0938
# #Epoch 157: Reconstruct Loss: 0.0808, Valid Reconstruct Loss: 0.0951
# #Epoch 158: Reconstruct Loss: 0.0807, Valid Reconstruct Loss: 0.0957
# #Epoch 159: Reconstruct Loss: 0.0809, Valid Reconstruct Loss: 0.0944
# #Epoch 160: Reconstruct Loss: 0.0807, Valid Reconstruct Loss: 0.0933
# #Epoch 161: Reconstruct Loss: 0.0806, Valid Reconstruct Loss: 0.0938
# #Epoch 162: Reconstruct Loss: 0.0806, Valid Reconstruct Loss: 0.0957
# #Epoch 163: Reconstruct Loss: 0.0805, Valid Reconstruct Loss: 0.0913
# #Epoch 164: Reconstruct Loss: 0.0805, Valid Reconstruct Loss: 0.0926
# #Epoch 165: Reconstruct Loss: 0.0804, Valid Reconstruct Loss: 0.0938
# #Epoch 166: Reconstruct Loss: 0.0803, Valid Reconstruct Loss: 0.0944
# #Epoch 167: Reconstruct Loss: 0.0804, Valid Reconstruct Loss: 0.0933
# #Epoch 168: Reconstruct Loss: 0.0803, Valid Reconstruct Loss: 0.0926
# #Epoch 169: Reconstruct Loss: 0.0802, Valid Reconstruct Loss: 0.0915
# #Epoch 170: Reconstruct Loss: 0.0801, Valid Reconstruct Loss: 0.0933
# #Epoch 171: Reconstruct Loss: 0.0802, Valid Reconstruct Loss: 0.0937
# #Epoch 172: Reconstruct Loss: 0.0802, Valid Reconstruct Loss: 0.0964
# #Epoch 173: Reconstruct Loss: 0.0801, Valid Reconstruct Loss: 0.0925
# #Epoch 174: Reconstruct Loss: 0.0800, Valid Reconstruct Loss: 0.0935
# #Epoch 175: Reconstruct Loss: 0.0799, Valid Reconstruct Loss: 0.0937
# #Epoch 176: Reconstruct Loss: 0.0800, Valid Reconstruct Loss: 0.0926
# #Epoch 177: Reconstruct Loss: 0.0799, Valid Reconstruct Loss: 0.0940
# #Epoch 178: Reconstruct Loss: 0.0797, Valid Reconstruct Loss: 0.0915
# #Epoch 179: Reconstruct Loss: 0.0798, Valid Reconstruct Loss: 0.0917
# #Epoch 180: Reconstruct Loss: 0.0797, Valid Reconstruct Loss: 0.0944
# #Epoch 181: Reconstruct Loss: 0.0797, Valid Reconstruct Loss: 0.0934
# #Epoch 182: Reconstruct Loss: 0.0796, Valid Reconstruct Loss: 0.0923
# #Epoch 183: Reconstruct Loss: 0.0796, Valid Reconstruct Loss: 0.0924
# #Epoch 184: Reconstruct Loss: 0.0795, Valid Reconstruct Loss: 0.0946
# #Epoch 185: Reconstruct Loss: 0.0795, Valid Reconstruct Loss: 0.0930
# #Epoch 186: Reconstruct Loss: 0.0795, Valid Reconstruct Loss: 0.0919
# #Epoch 187: Reconstruct Loss: 0.0793, Valid Reconstruct Loss: 0.0925
# #Epoch 188: Reconstruct Loss: 0.0794, Valid Reconstruct Loss: 0.0924
# #Epoch 189: Reconstruct Loss: 0.0793, Valid Reconstruct Loss: 0.0932
# #Epoch 190: Reconstruct Loss: 0.0792, Valid Reconstruct Loss: 0.0915
# #Epoch 191: Reconstruct Loss: 0.0791, Valid Reconstruct Loss: 0.0912
# #Epoch 192: Reconstruct Loss: 0.0792, Valid Reconstruct Loss: 0.0920
# #Epoch 193: Reconstruct Loss: 0.0791, Valid Reconstruct Loss: 0.0930
# #Epoch 194: Reconstruct Loss: 0.0791, Valid Reconstruct Loss: 0.0916
# #Epoch 195: Reconstruct Loss: 0.0790, Valid Reconstruct Loss: 0.0927
# #Epoch 196: Reconstruct Loss: 0.0790, Valid Reconstruct Loss: 0.0910
# #Epoch 197: Reconstruct Loss: 0.0789, Valid Reconstruct Loss: 0.0925
# #Epoch 198: Reconstruct Loss: 0.0789, Valid Reconstruct Loss: 0.0923
# #Epoch 199: Reconstruct Loss: 0.0788, Valid Reconstruct Loss: 0.0928
# #Epoch 200: Reconstruct Loss: 0.0788, Valid Reconstruct Loss: 0.0914
# Switching to learning rate 0.001000
# #Epoch 201: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0915
# #Epoch 202: Reconstruct Loss: 0.0789, Valid Reconstruct Loss: 0.0918
# #Epoch 203: Reconstruct Loss: 0.0788, Valid Reconstruct Loss: 0.0919
# #Epoch 204: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0914
# #Epoch 205: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0912
# #Epoch 206: Reconstruct Loss: 0.0788, Valid Reconstruct Loss: 0.0917
# #Epoch 207: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0917
# #Epoch 208: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0913
# #Epoch 209: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0913
# #Epoch 210: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0919
# #Epoch 211: Reconstruct Loss: 0.0788, Valid Reconstruct Loss: 0.0917
# #Epoch 212: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0918
# #Epoch 213: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0926
# #Epoch 214: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0923
# #Epoch 215: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0925
# #Epoch 216: Reconstruct Loss: 0.0788, Valid Reconstruct Loss: 0.0918
# #Epoch 217: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0915
# #Epoch 218: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0913
# #Epoch 219: Reconstruct Loss: 0.0789, Valid Reconstruct Loss: 0.0924
# #Epoch 220: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0919
# #Epoch 221: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0917
# #Epoch 222: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0918
# #Epoch 223: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0926
# #Epoch 224: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0919
# #Epoch 225: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0918
# #Epoch 226: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0910
# #Epoch 227: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0916
# #Epoch 228: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0919
# #Epoch 229: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0914
# #Epoch 230: Reconstruct Loss: 0.0787, Valid Reconstruct Loss: 0.0919
# #Epoch 231: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0918
# #Epoch 232: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0918
# #Epoch 233: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0920
# #Epoch 234: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0914
# #Epoch 235: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0918
# #Epoch 236: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0919
# #Epoch 237: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0923
# #Epoch 238: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0917
# #Epoch 239: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0915
# #Epoch 240: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0911
# #Epoch 241: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0916
# #Epoch 242: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0919
# #Epoch 243: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0919
# #Epoch 244: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0915
# #Epoch 245: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0916
# #Epoch 246: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0916
# #Epoch 247: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0915
# #Epoch 248: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0916
# #Epoch 249: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0912
# #Epoch 250: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0911
# #Epoch 251: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0912
# #Epoch 252: Reconstruct Loss: 0.0786, Valid Reconstruct Loss: 0.0919
# #Epoch 253: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0920
# #Epoch 254: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0917
# #Epoch 255: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0914
# #Epoch 256: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0917
# #Epoch 257: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0914
# #Epoch 258: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0914
# #Epoch 259: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0911
# #Epoch 260: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0912
# #Epoch 261: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0915
# #Epoch 262: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0914
# #Epoch 263: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0913
# #Epoch 264: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0913
# #Epoch 265: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0914
# #Epoch 266: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0916
# #Epoch 267: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0918
# #Epoch 268: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0911
# #Epoch 269: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0910
# #Epoch 270: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0913
# #Epoch 271: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0914
# #Epoch 272: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0913
# #Epoch 273: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0927
# #Epoch 274: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0914
# #Epoch 275: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0915
# #Epoch 276: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0916
# #Epoch 277: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0915
# #Epoch 278: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0914
# #Epoch 279: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0911
# #Epoch 280: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0909
# #Epoch 281: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0913
# #Epoch 282: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0910
# #Epoch 283: Reconstruct Loss: 0.0785, Valid Reconstruct Loss: 0.0917
# #Epoch 284: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0919
# #Epoch 285: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0915
# #Epoch 286: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0917
# #Epoch 287: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0917
# #Epoch 288: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0917
# #Epoch 289: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0912
# #Epoch 290: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0907
# #Epoch 291: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0908
# #Epoch 292: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0911
# #Epoch 293: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0916
# #Epoch 294: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0914
# #Epoch 295: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0911
# #Epoch 296: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0909
# #Epoch 297: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0907
# #Epoch 298: Reconstruct Loss: 0.0782, Valid Reconstruct Loss: 0.0913
# #Epoch 299: Reconstruct Loss: 0.0783, Valid Reconstruct Loss: 0.0909
# #Epoch 300: Reconstruct Loss: 0.0784, Valid Reconstruct Loss: 0.0914
# DenoisingAutoencoder(
#   in_features=500, out_features=500, bias=True
#   (enc_act_func): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# =====Denoising Autoencoding layer=======
# #Epoch 0: Valid Reconstruct Loss: 2.0053
# #Epoch   1: Reconstruct Loss: 1.4288, Valid Reconstruct Loss: 0.8770
# #Epoch   2: Reconstruct Loss: 0.7388, Valid Reconstruct Loss: 0.6734
# #Epoch   3: Reconstruct Loss: 0.5833, Valid Reconstruct Loss: 0.5446
# #Epoch   4: Reconstruct Loss: 0.4882, Valid Reconstruct Loss: 0.4982
# #Epoch   5: Reconstruct Loss: 0.4411, Valid Reconstruct Loss: 0.4593
# #Epoch   6: Reconstruct Loss: 0.4123, Valid Reconstruct Loss: 0.4445
# #Epoch   7: Reconstruct Loss: 0.3904, Valid Reconstruct Loss: 0.4430
# #Epoch   8: Reconstruct Loss: 0.3723, Valid Reconstruct Loss: 0.4209
# #Epoch   9: Reconstruct Loss: 0.3563, Valid Reconstruct Loss: 0.3868
# #Epoch  10: Reconstruct Loss: 0.3437, Valid Reconstruct Loss: 0.3892
# #Epoch  11: Reconstruct Loss: 0.3330, Valid Reconstruct Loss: 0.3750
# #Epoch  12: Reconstruct Loss: 0.3235, Valid Reconstruct Loss: 0.3498
# #Epoch  13: Reconstruct Loss: 0.3143, Valid Reconstruct Loss: 0.3424
# #Epoch  14: Reconstruct Loss: 0.3069, Valid Reconstruct Loss: 0.3269
# #Epoch  15: Reconstruct Loss: 0.2992, Valid Reconstruct Loss: 0.3296
# #Epoch  16: Reconstruct Loss: 0.2937, Valid Reconstruct Loss: 0.3141
# #Epoch  17: Reconstruct Loss: 0.2877, Valid Reconstruct Loss: 0.3051
# #Epoch  18: Reconstruct Loss: 0.2814, Valid Reconstruct Loss: 0.3004
# #Epoch  19: Reconstruct Loss: 0.2769, Valid Reconstruct Loss: 0.2928
# #Epoch  20: Reconstruct Loss: 0.2727, Valid Reconstruct Loss: 0.2786
# #Epoch  21: Reconstruct Loss: 0.2707, Valid Reconstruct Loss: 0.2676
# #Epoch  22: Reconstruct Loss: 0.2654, Valid Reconstruct Loss: 0.2698
# #Epoch  23: Reconstruct Loss: 0.2625, Valid Reconstruct Loss: 0.2740
# #Epoch  24: Reconstruct Loss: 0.2595, Valid Reconstruct Loss: 0.2836
# #Epoch  25: Reconstruct Loss: 0.2588, Valid Reconstruct Loss: 0.2854
# #Epoch  26: Reconstruct Loss: 0.2544, Valid Reconstruct Loss: 0.2651
# #Epoch  27: Reconstruct Loss: 0.2517, Valid Reconstruct Loss: 0.2676
# #Epoch  28: Reconstruct Loss: 0.2494, Valid Reconstruct Loss: 0.2808
# #Epoch  29: Reconstruct Loss: 0.2464, Valid Reconstruct Loss: 0.2523
# #Epoch  30: Reconstruct Loss: 0.2452, Valid Reconstruct Loss: 0.2514
# #Epoch  31: Reconstruct Loss: 0.2427, Valid Reconstruct Loss: 0.2338
# #Epoch  32: Reconstruct Loss: 0.2422, Valid Reconstruct Loss: 0.2442
# #Epoch  33: Reconstruct Loss: 0.2410, Valid Reconstruct Loss: 0.2387
# #Epoch  34: Reconstruct Loss: 0.2405, Valid Reconstruct Loss: 0.2443
# #Epoch  35: Reconstruct Loss: 0.2371, Valid Reconstruct Loss: 0.2582
# #Epoch  36: Reconstruct Loss: 0.2347, Valid Reconstruct Loss: 0.2170
# #Epoch  37: Reconstruct Loss: 0.2348, Valid Reconstruct Loss: 0.2317
# #Epoch  38: Reconstruct Loss: 0.2324, Valid Reconstruct Loss: 0.2518
# #Epoch  39: Reconstruct Loss: 0.2303, Valid Reconstruct Loss: 0.2195
# #Epoch  40: Reconstruct Loss: 0.2306, Valid Reconstruct Loss: 0.2345
# #Epoch  41: Reconstruct Loss: 0.2295, Valid Reconstruct Loss: 0.2818
# #Epoch  42: Reconstruct Loss: 0.2285, Valid Reconstruct Loss: 0.2281
# #Epoch  43: Reconstruct Loss: 0.2279, Valid Reconstruct Loss: 0.2122
# #Epoch  44: Reconstruct Loss: 0.2258, Valid Reconstruct Loss: 0.2440
# #Epoch  45: Reconstruct Loss: 0.2258, Valid Reconstruct Loss: 0.2450
# #Epoch  46: Reconstruct Loss: 0.2243, Valid Reconstruct Loss: 0.2102
# #Epoch  47: Reconstruct Loss: 0.2224, Valid Reconstruct Loss: 0.2135
# #Epoch  48: Reconstruct Loss: 0.2217, Valid Reconstruct Loss: 0.2288
# #Epoch  49: Reconstruct Loss: 0.2212, Valid Reconstruct Loss: 0.2282
# #Epoch  50: Reconstruct Loss: 0.2201, Valid Reconstruct Loss: 0.2260
# #Epoch  51: Reconstruct Loss: 0.2196, Valid Reconstruct Loss: 0.2100
# #Epoch  52: Reconstruct Loss: 0.2186, Valid Reconstruct Loss: 0.2246
# #Epoch  53: Reconstruct Loss: 0.2191, Valid Reconstruct Loss: 0.2050
# #Epoch  54: Reconstruct Loss: 0.2172, Valid Reconstruct Loss: 0.2146
# #Epoch  55: Reconstruct Loss: 0.2175, Valid Reconstruct Loss: 0.2147
# #Epoch  56: Reconstruct Loss: 0.2164, Valid Reconstruct Loss: 0.1984
# #Epoch  57: Reconstruct Loss: 0.2168, Valid Reconstruct Loss: 0.2374
# #Epoch  58: Reconstruct Loss: 0.2168, Valid Reconstruct Loss: 0.2238
# #Epoch  59: Reconstruct Loss: 0.2153, Valid Reconstruct Loss: 0.2077
# #Epoch  60: Reconstruct Loss: 0.2138, Valid Reconstruct Loss: 0.2049
# #Epoch  61: Reconstruct Loss: 0.2129, Valid Reconstruct Loss: 0.2007
# #Epoch  62: Reconstruct Loss: 0.2134, Valid Reconstruct Loss: 0.1859
# #Epoch  63: Reconstruct Loss: 0.2133, Valid Reconstruct Loss: 0.2164
# #Epoch  64: Reconstruct Loss: 0.2115, Valid Reconstruct Loss: 0.1998
# #Epoch  65: Reconstruct Loss: 0.2121, Valid Reconstruct Loss: 0.2202
# #Epoch  66: Reconstruct Loss: 0.2111, Valid Reconstruct Loss: 0.1869
# #Epoch  67: Reconstruct Loss: 0.2107, Valid Reconstruct Loss: 0.1920
# #Epoch  68: Reconstruct Loss: 0.2132, Valid Reconstruct Loss: 0.1943
# #Epoch  69: Reconstruct Loss: 0.2105, Valid Reconstruct Loss: 0.1972
# #Epoch  70: Reconstruct Loss: 0.2103, Valid Reconstruct Loss: 0.1959
# #Epoch  71: Reconstruct Loss: 0.2091, Valid Reconstruct Loss: 0.1987
# #Epoch  72: Reconstruct Loss: 0.2093, Valid Reconstruct Loss: 0.1931
# #Epoch  73: Reconstruct Loss: 0.2079, Valid Reconstruct Loss: 0.1999
# #Epoch  74: Reconstruct Loss: 0.2087, Valid Reconstruct Loss: 0.1984
# #Epoch  75: Reconstruct Loss: 0.2081, Valid Reconstruct Loss: 0.1948
# #Epoch  76: Reconstruct Loss: 0.2091, Valid Reconstruct Loss: 0.1937
# #Epoch  77: Reconstruct Loss: 0.2078, Valid Reconstruct Loss: 0.2210
# #Epoch  78: Reconstruct Loss: 0.2081, Valid Reconstruct Loss: 0.1789
# #Epoch  79: Reconstruct Loss: 0.2084, Valid Reconstruct Loss: 0.1944
# #Epoch  80: Reconstruct Loss: 0.2072, Valid Reconstruct Loss: 0.1801
# #Epoch  81: Reconstruct Loss: 0.2091, Valid Reconstruct Loss: 0.1841
# #Epoch  82: Reconstruct Loss: 0.2059, Valid Reconstruct Loss: 0.1892
# #Epoch  83: Reconstruct Loss: 0.2049, Valid Reconstruct Loss: 0.2056
# #Epoch  84: Reconstruct Loss: 0.2063, Valid Reconstruct Loss: 0.1930
# #Epoch  85: Reconstruct Loss: 0.2066, Valid Reconstruct Loss: 0.2050
# #Epoch  86: Reconstruct Loss: 0.2059, Valid Reconstruct Loss: 0.1894
# #Epoch  87: Reconstruct Loss: 0.2042, Valid Reconstruct Loss: 0.1981
# #Epoch  88: Reconstruct Loss: 0.2055, Valid Reconstruct Loss: 0.1913
# #Epoch  89: Reconstruct Loss: 0.2042, Valid Reconstruct Loss: 0.1802
# #Epoch  90: Reconstruct Loss: 0.2068, Valid Reconstruct Loss: 0.1982
# #Epoch  91: Reconstruct Loss: 0.2031, Valid Reconstruct Loss: 0.1773
# #Epoch  92: Reconstruct Loss: 0.2057, Valid Reconstruct Loss: 0.1972
# #Epoch  93: Reconstruct Loss: 0.2045, Valid Reconstruct Loss: 0.1892
# #Epoch  94: Reconstruct Loss: 0.2043, Valid Reconstruct Loss: 0.2048
# #Epoch  95: Reconstruct Loss: 0.2033, Valid Reconstruct Loss: 0.2046
# #Epoch  96: Reconstruct Loss: 0.2031, Valid Reconstruct Loss: 0.1877
# #Epoch  97: Reconstruct Loss: 0.2026, Valid Reconstruct Loss: 0.2068
# #Epoch  98: Reconstruct Loss: 0.2023, Valid Reconstruct Loss: 0.1908
# #Epoch  99: Reconstruct Loss: 0.2024, Valid Reconstruct Loss: 0.2005
# #Epoch 100: Reconstruct Loss: 0.2018, Valid Reconstruct Loss: 0.1882
# Switching to learning rate 0.010000
# #Epoch 101: Reconstruct Loss: 0.2007, Valid Reconstruct Loss: 0.1805
# #Epoch 102: Reconstruct Loss: 0.1994, Valid Reconstruct Loss: 0.1859
# #Epoch 103: Reconstruct Loss: 0.1989, Valid Reconstruct Loss: 0.1829
# #Epoch 104: Reconstruct Loss: 0.1991, Valid Reconstruct Loss: 0.1846
# #Epoch 105: Reconstruct Loss: 0.1988, Valid Reconstruct Loss: 0.1817
# #Epoch 106: Reconstruct Loss: 0.1990, Valid Reconstruct Loss: 0.1859
# #Epoch 107: Reconstruct Loss: 0.1991, Valid Reconstruct Loss: 0.1794
# #Epoch 108: Reconstruct Loss: 0.1998, Valid Reconstruct Loss: 0.1833
# #Epoch 109: Reconstruct Loss: 0.1982, Valid Reconstruct Loss: 0.1828
# #Epoch 110: Reconstruct Loss: 0.1989, Valid Reconstruct Loss: 0.1861
# #Epoch 111: Reconstruct Loss: 0.1987, Valid Reconstruct Loss: 0.1849
# #Epoch 112: Reconstruct Loss: 0.1993, Valid Reconstruct Loss: 0.1823
# #Epoch 113: Reconstruct Loss: 0.1994, Valid Reconstruct Loss: 0.1848
# #Epoch 114: Reconstruct Loss: 0.1984, Valid Reconstruct Loss: 0.1863
# #Epoch 115: Reconstruct Loss: 0.1984, Valid Reconstruct Loss: 0.1846
# #Epoch 116: Reconstruct Loss: 0.1982, Valid Reconstruct Loss: 0.1796
# #Epoch 117: Reconstruct Loss: 0.1993, Valid Reconstruct Loss: 0.1846
# #Epoch 118: Reconstruct Loss: 0.1980, Valid Reconstruct Loss: 0.1824
# #Epoch 119: Reconstruct Loss: 0.1987, Valid Reconstruct Loss: 0.1864
# #Epoch 120: Reconstruct Loss: 0.1978, Valid Reconstruct Loss: 0.1805
# #Epoch 121: Reconstruct Loss: 0.1985, Valid Reconstruct Loss: 0.1889
# #Epoch 122: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1872
# #Epoch 123: Reconstruct Loss: 0.1989, Valid Reconstruct Loss: 0.1836
# #Epoch 124: Reconstruct Loss: 0.1978, Valid Reconstruct Loss: 0.1773
# #Epoch 125: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1886
# #Epoch 126: Reconstruct Loss: 0.1975, Valid Reconstruct Loss: 0.1831
# #Epoch 127: Reconstruct Loss: 0.1985, Valid Reconstruct Loss: 0.1841
# #Epoch 128: Reconstruct Loss: 0.1981, Valid Reconstruct Loss: 0.1813
# #Epoch 129: Reconstruct Loss: 0.1981, Valid Reconstruct Loss: 0.1858
# #Epoch 130: Reconstruct Loss: 0.1986, Valid Reconstruct Loss: 0.1833
# #Epoch 131: Reconstruct Loss: 0.1981, Valid Reconstruct Loss: 0.1825
# #Epoch 132: Reconstruct Loss: 0.1980, Valid Reconstruct Loss: 0.1791
# #Epoch 133: Reconstruct Loss: 0.1984, Valid Reconstruct Loss: 0.1868
# #Epoch 134: Reconstruct Loss: 0.1987, Valid Reconstruct Loss: 0.1799
# #Epoch 135: Reconstruct Loss: 0.1976, Valid Reconstruct Loss: 0.1825
# #Epoch 136: Reconstruct Loss: 0.1974, Valid Reconstruct Loss: 0.1853
# #Epoch 137: Reconstruct Loss: 0.1980, Valid Reconstruct Loss: 0.1825
# #Epoch 138: Reconstruct Loss: 0.1982, Valid Reconstruct Loss: 0.1838
# #Epoch 139: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1802
# #Epoch 140: Reconstruct Loss: 0.1978, Valid Reconstruct Loss: 0.1772
# #Epoch 141: Reconstruct Loss: 0.1983, Valid Reconstruct Loss: 0.1787
# #Epoch 142: Reconstruct Loss: 0.1978, Valid Reconstruct Loss: 0.1826
# #Epoch 143: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1812
# #Epoch 144: Reconstruct Loss: 0.1983, Valid Reconstruct Loss: 0.1863
# #Epoch 145: Reconstruct Loss: 0.1984, Valid Reconstruct Loss: 0.1832
# #Epoch 146: Reconstruct Loss: 0.1979, Valid Reconstruct Loss: 0.1872
# #Epoch 147: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1815
# #Epoch 148: Reconstruct Loss: 0.1979, Valid Reconstruct Loss: 0.1842
# #Epoch 149: Reconstruct Loss: 0.1986, Valid Reconstruct Loss: 0.1784
# #Epoch 150: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1835
# #Epoch 151: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1788
# #Epoch 152: Reconstruct Loss: 0.1979, Valid Reconstruct Loss: 0.1817
# #Epoch 153: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1861
# #Epoch 154: Reconstruct Loss: 0.1974, Valid Reconstruct Loss: 0.1785
# #Epoch 155: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1846
# #Epoch 156: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1814
# #Epoch 157: Reconstruct Loss: 0.1985, Valid Reconstruct Loss: 0.1822
# #Epoch 158: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1821
# #Epoch 159: Reconstruct Loss: 0.1968, Valid Reconstruct Loss: 0.1836
# #Epoch 160: Reconstruct Loss: 0.1972, Valid Reconstruct Loss: 0.1780
# #Epoch 161: Reconstruct Loss: 0.1973, Valid Reconstruct Loss: 0.1805
# #Epoch 162: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1824
# #Epoch 163: Reconstruct Loss: 0.1973, Valid Reconstruct Loss: 0.1822
# #Epoch 164: Reconstruct Loss: 0.1978, Valid Reconstruct Loss: 0.1802
# #Epoch 165: Reconstruct Loss: 0.1976, Valid Reconstruct Loss: 0.1833
# #Epoch 166: Reconstruct Loss: 0.1980, Valid Reconstruct Loss: 0.1836
# #Epoch 167: Reconstruct Loss: 0.1976, Valid Reconstruct Loss: 0.1829
# #Epoch 168: Reconstruct Loss: 0.1976, Valid Reconstruct Loss: 0.1732
# #Epoch 169: Reconstruct Loss: 0.1975, Valid Reconstruct Loss: 0.1816
# #Epoch 170: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1807
# #Epoch 171: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1837
# #Epoch 172: Reconstruct Loss: 0.1976, Valid Reconstruct Loss: 0.1820
# #Epoch 173: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1827
# #Epoch 174: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1808
# #Epoch 175: Reconstruct Loss: 0.1974, Valid Reconstruct Loss: 0.1796
# #Epoch 176: Reconstruct Loss: 0.1974, Valid Reconstruct Loss: 0.1842
# #Epoch 177: Reconstruct Loss: 0.1970, Valid Reconstruct Loss: 0.1839
# #Epoch 178: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1769
# #Epoch 179: Reconstruct Loss: 0.1970, Valid Reconstruct Loss: 0.1855
# #Epoch 180: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1828
# #Epoch 181: Reconstruct Loss: 0.1977, Valid Reconstruct Loss: 0.1844
# #Epoch 182: Reconstruct Loss: 0.1972, Valid Reconstruct Loss: 0.1792
# #Epoch 183: Reconstruct Loss: 0.1970, Valid Reconstruct Loss: 0.1812
# #Epoch 184: Reconstruct Loss: 0.1973, Valid Reconstruct Loss: 0.1836
# #Epoch 185: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1782
# #Epoch 186: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1830
# #Epoch 187: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1785
# #Epoch 188: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1850
# #Epoch 189: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1775
# #Epoch 190: Reconstruct Loss: 0.1972, Valid Reconstruct Loss: 0.1802
# #Epoch 191: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1836
# #Epoch 192: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1843
# #Epoch 193: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1813
# #Epoch 194: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1763
# #Epoch 195: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1820
# #Epoch 196: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1770
# #Epoch 197: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1773
# #Epoch 198: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1814
# #Epoch 199: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1849
# #Epoch 200: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1803
# Switching to learning rate 0.001000
# #Epoch 201: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1820
# #Epoch 202: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1811
# #Epoch 203: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1791
# #Epoch 204: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1799
# #Epoch 205: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1800
# #Epoch 206: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1786
# #Epoch 207: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1796
# #Epoch 208: Reconstruct Loss: 0.1960, Valid Reconstruct Loss: 0.1805
# #Epoch 209: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1812
# #Epoch 210: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1810
# #Epoch 211: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1797
# #Epoch 212: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1805
# #Epoch 213: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1798
# #Epoch 214: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1801
# #Epoch 215: Reconstruct Loss: 0.1974, Valid Reconstruct Loss: 0.1805
# #Epoch 216: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1812
# #Epoch 217: Reconstruct Loss: 0.1960, Valid Reconstruct Loss: 0.1791
# #Epoch 218: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1790
# #Epoch 219: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1806
# #Epoch 220: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1813
# #Epoch 221: Reconstruct Loss: 0.1973, Valid Reconstruct Loss: 0.1806
# #Epoch 222: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1784
# #Epoch 223: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1790
# #Epoch 224: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1781
# #Epoch 225: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1769
# #Epoch 226: Reconstruct Loss: 0.1960, Valid Reconstruct Loss: 0.1788
# #Epoch 227: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1794
# #Epoch 228: Reconstruct Loss: 0.1968, Valid Reconstruct Loss: 0.1796
# #Epoch 229: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1806
# #Epoch 230: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1808
# #Epoch 231: Reconstruct Loss: 0.1956, Valid Reconstruct Loss: 0.1803
# #Epoch 232: Reconstruct Loss: 0.1960, Valid Reconstruct Loss: 0.1799
# #Epoch 233: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1790
# #Epoch 234: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1791
# #Epoch 235: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1793
# #Epoch 236: Reconstruct Loss: 0.1956, Valid Reconstruct Loss: 0.1798
# #Epoch 237: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1794
# #Epoch 238: Reconstruct Loss: 0.1960, Valid Reconstruct Loss: 0.1818
# #Epoch 239: Reconstruct Loss: 0.1972, Valid Reconstruct Loss: 0.1804
# #Epoch 240: Reconstruct Loss: 0.1954, Valid Reconstruct Loss: 0.1785
# #Epoch 241: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1794
# #Epoch 242: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1800
# #Epoch 243: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1789
# #Epoch 244: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1794
# #Epoch 245: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1785
# #Epoch 246: Reconstruct Loss: 0.1972, Valid Reconstruct Loss: 0.1786
# #Epoch 247: Reconstruct Loss: 0.1968, Valid Reconstruct Loss: 0.1803
# #Epoch 248: Reconstruct Loss: 0.1947, Valid Reconstruct Loss: 0.1805
# #Epoch 249: Reconstruct Loss: 0.1972, Valid Reconstruct Loss: 0.1795
# #Epoch 250: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1791
# #Epoch 251: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1805
# #Epoch 252: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1822
# #Epoch 253: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1816
# #Epoch 254: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1818
# #Epoch 255: Reconstruct Loss: 0.1968, Valid Reconstruct Loss: 0.1800
# #Epoch 256: Reconstruct Loss: 0.1971, Valid Reconstruct Loss: 0.1780
# #Epoch 257: Reconstruct Loss: 0.1955, Valid Reconstruct Loss: 0.1791
# #Epoch 258: Reconstruct Loss: 0.1956, Valid Reconstruct Loss: 0.1800
# #Epoch 259: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1792
# #Epoch 260: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1807
# #Epoch 261: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1814
# #Epoch 262: Reconstruct Loss: 0.1973, Valid Reconstruct Loss: 0.1802
# #Epoch 263: Reconstruct Loss: 0.1963, Valid Reconstruct Loss: 0.1801
# #Epoch 264: Reconstruct Loss: 0.1955, Valid Reconstruct Loss: 0.1804
# #Epoch 265: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1795
# #Epoch 266: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1803
# #Epoch 267: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1805
# #Epoch 268: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1814
# #Epoch 269: Reconstruct Loss: 0.1957, Valid Reconstruct Loss: 0.1818
# #Epoch 270: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1805
# #Epoch 271: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1798
# #Epoch 272: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1792
# #Epoch 273: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1796
# #Epoch 274: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1818
# #Epoch 275: Reconstruct Loss: 0.1961, Valid Reconstruct Loss: 0.1828
# #Epoch 276: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1811
# #Epoch 277: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1792
# #Epoch 278: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1795
# #Epoch 279: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1827
# #Epoch 280: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1817
# #Epoch 281: Reconstruct Loss: 0.1970, Valid Reconstruct Loss: 0.1820
# #Epoch 282: Reconstruct Loss: 0.1956, Valid Reconstruct Loss: 0.1806
# #Epoch 283: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1802
# #Epoch 284: Reconstruct Loss: 0.1952, Valid Reconstruct Loss: 0.1792
# #Epoch 285: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1786
# #Epoch 286: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1793
# #Epoch 287: Reconstruct Loss: 0.1969, Valid Reconstruct Loss: 0.1777
# #Epoch 288: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1788
# #Epoch 289: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1787
# #Epoch 290: Reconstruct Loss: 0.1964, Valid Reconstruct Loss: 0.1785
# #Epoch 291: Reconstruct Loss: 0.1953, Valid Reconstruct Loss: 0.1797
# #Epoch 292: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1799
# #Epoch 293: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1805
# #Epoch 294: Reconstruct Loss: 0.1965, Valid Reconstruct Loss: 0.1794
# #Epoch 295: Reconstruct Loss: 0.1958, Valid Reconstruct Loss: 0.1813
# #Epoch 296: Reconstruct Loss: 0.1966, Valid Reconstruct Loss: 0.1818
# #Epoch 297: Reconstruct Loss: 0.1962, Valid Reconstruct Loss: 0.1804
# #Epoch 298: Reconstruct Loss: 0.1967, Valid Reconstruct Loss: 0.1796
# #Epoch 299: Reconstruct Loss: 0.1954, Valid Reconstruct Loss: 0.1797
# #Epoch 300: Reconstruct Loss: 0.1959, Valid Reconstruct Loss: 0.1791
# DenoisingAutoencoder(
#   in_features=500, out_features=2000, bias=True
#   (enc_act_func): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# =====Denoising Autoencoding layer=======
# #Epoch 0: Valid Reconstruct Loss: 0.9145
# #Epoch   1: Reconstruct Loss: 0.7546, Valid Reconstruct Loss: 0.5682
# #Epoch   2: Reconstruct Loss: 0.4760, Valid Reconstruct Loss: 0.4243
# #Epoch   3: Reconstruct Loss: 0.3914, Valid Reconstruct Loss: 0.3691
# #Epoch   4: Reconstruct Loss: 0.3380, Valid Reconstruct Loss: 0.3169
# #Epoch   5: Reconstruct Loss: 0.2996, Valid Reconstruct Loss: 0.2939
# #Epoch   6: Reconstruct Loss: 0.2758, Valid Reconstruct Loss: 0.2741
# #Epoch   7: Reconstruct Loss: 0.2574, Valid Reconstruct Loss: 0.2575
# #Epoch   8: Reconstruct Loss: 0.2402, Valid Reconstruct Loss: 0.2381
# #Epoch   9: Reconstruct Loss: 0.2258, Valid Reconstruct Loss: 0.2258
# #Epoch  10: Reconstruct Loss: 0.2142, Valid Reconstruct Loss: 0.2143
# #Epoch  11: Reconstruct Loss: 0.2037, Valid Reconstruct Loss: 0.2032
# #Epoch  12: Reconstruct Loss: 0.1945, Valid Reconstruct Loss: 0.1924
# #Epoch  13: Reconstruct Loss: 0.1865, Valid Reconstruct Loss: 0.1849
# #Epoch  14: Reconstruct Loss: 0.1789, Valid Reconstruct Loss: 0.1777
# #Epoch  15: Reconstruct Loss: 0.1726, Valid Reconstruct Loss: 0.1707
# #Epoch  16: Reconstruct Loss: 0.1663, Valid Reconstruct Loss: 0.1635
# #Epoch  17: Reconstruct Loss: 0.1609, Valid Reconstruct Loss: 0.1581
# #Epoch  18: Reconstruct Loss: 0.1565, Valid Reconstruct Loss: 0.1566
# #Epoch  19: Reconstruct Loss: 0.1519, Valid Reconstruct Loss: 0.1506
# #Epoch  20: Reconstruct Loss: 0.1483, Valid Reconstruct Loss: 0.1470
# #Epoch  21: Reconstruct Loss: 0.1449, Valid Reconstruct Loss: 0.1426
# #Epoch  22: Reconstruct Loss: 0.1419, Valid Reconstruct Loss: 0.1399
# #Epoch  23: Reconstruct Loss: 0.1388, Valid Reconstruct Loss: 0.1355
# #Epoch  24: Reconstruct Loss: 0.1364, Valid Reconstruct Loss: 0.1330
# #Epoch  25: Reconstruct Loss: 0.1331, Valid Reconstruct Loss: 0.1296
# #Epoch  26: Reconstruct Loss: 0.1310, Valid Reconstruct Loss: 0.1271
# #Epoch  27: Reconstruct Loss: 0.1286, Valid Reconstruct Loss: 0.1260
# #Epoch  28: Reconstruct Loss: 0.1268, Valid Reconstruct Loss: 0.1256
# #Epoch  29: Reconstruct Loss: 0.1247, Valid Reconstruct Loss: 0.1206
# #Epoch  30: Reconstruct Loss: 0.1231, Valid Reconstruct Loss: 0.1206
# #Epoch  31: Reconstruct Loss: 0.1210, Valid Reconstruct Loss: 0.1193
# #Epoch  32: Reconstruct Loss: 0.1195, Valid Reconstruct Loss: 0.1157
# #Epoch  33: Reconstruct Loss: 0.1179, Valid Reconstruct Loss: 0.1144
# #Epoch  34: Reconstruct Loss: 0.1168, Valid Reconstruct Loss: 0.1128
# #Epoch  35: Reconstruct Loss: 0.1152, Valid Reconstruct Loss: 0.1109
# #Epoch  36: Reconstruct Loss: 0.1144, Valid Reconstruct Loss: 0.1102
# #Epoch  37: Reconstruct Loss: 0.1130, Valid Reconstruct Loss: 0.1071
# #Epoch  38: Reconstruct Loss: 0.1119, Valid Reconstruct Loss: 0.1070
# #Epoch  39: Reconstruct Loss: 0.1107, Valid Reconstruct Loss: 0.1070
# #Epoch  40: Reconstruct Loss: 0.1097, Valid Reconstruct Loss: 0.1061
# #Epoch  41: Reconstruct Loss: 0.1089, Valid Reconstruct Loss: 0.1035
# #Epoch  42: Reconstruct Loss: 0.1076, Valid Reconstruct Loss: 0.1025
# #Epoch  43: Reconstruct Loss: 0.1074, Valid Reconstruct Loss: 0.1030
# #Epoch  44: Reconstruct Loss: 0.1073, Valid Reconstruct Loss: 0.1007
# #Epoch  45: Reconstruct Loss: 0.1060, Valid Reconstruct Loss: 0.1012
# #Epoch  46: Reconstruct Loss: 0.1045, Valid Reconstruct Loss: 0.1005
# #Epoch  47: Reconstruct Loss: 0.1040, Valid Reconstruct Loss: 0.0985
# #Epoch  48: Reconstruct Loss: 0.1035, Valid Reconstruct Loss: 0.0974
# #Epoch  49: Reconstruct Loss: 0.1028, Valid Reconstruct Loss: 0.0977
# #Epoch  50: Reconstruct Loss: 0.1023, Valid Reconstruct Loss: 0.0966
# #Epoch  51: Reconstruct Loss: 0.1015, Valid Reconstruct Loss: 0.0970
# #Epoch  52: Reconstruct Loss: 0.1010, Valid Reconstruct Loss: 0.0973
# #Epoch  53: Reconstruct Loss: 0.1005, Valid Reconstruct Loss: 0.0960
# #Epoch  54: Reconstruct Loss: 0.0996, Valid Reconstruct Loss: 0.0931
# #Epoch  55: Reconstruct Loss: 0.0996, Valid Reconstruct Loss: 0.0934
# #Epoch  56: Reconstruct Loss: 0.0989, Valid Reconstruct Loss: 0.0938
# #Epoch  57: Reconstruct Loss: 0.0979, Valid Reconstruct Loss: 0.0913
# #Epoch  58: Reconstruct Loss: 0.0981, Valid Reconstruct Loss: 0.0921
# #Epoch  59: Reconstruct Loss: 0.0976, Valid Reconstruct Loss: 0.0930
# #Epoch  60: Reconstruct Loss: 0.0982, Valid Reconstruct Loss: 0.0905
# #Epoch  61: Reconstruct Loss: 0.0971, Valid Reconstruct Loss: 0.0872
# #Epoch  62: Reconstruct Loss: 0.0963, Valid Reconstruct Loss: 0.0868
# #Epoch  63: Reconstruct Loss: 0.0957, Valid Reconstruct Loss: 0.0905
# #Epoch  64: Reconstruct Loss: 0.0953, Valid Reconstruct Loss: 0.0872
# #Epoch  65: Reconstruct Loss: 0.0949, Valid Reconstruct Loss: 0.0879
# #Epoch  66: Reconstruct Loss: 0.0946, Valid Reconstruct Loss: 0.0870
# #Epoch  67: Reconstruct Loss: 0.0933, Valid Reconstruct Loss: 0.0843
# #Epoch  68: Reconstruct Loss: 0.0935, Valid Reconstruct Loss: 0.0868
# #Epoch  69: Reconstruct Loss: 0.0932, Valid Reconstruct Loss: 0.0845
# #Epoch  70: Reconstruct Loss: 0.0929, Valid Reconstruct Loss: 0.0846
# #Epoch  71: Reconstruct Loss: 0.0927, Valid Reconstruct Loss: 0.0836
# #Epoch  72: Reconstruct Loss: 0.0922, Valid Reconstruct Loss: 0.0846
# #Epoch  73: Reconstruct Loss: 0.0919, Valid Reconstruct Loss: 0.0842
# #Epoch  74: Reconstruct Loss: 0.0918, Valid Reconstruct Loss: 0.0836
# ...
# #Epoch 271: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 272: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 273: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 274: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 275: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1009
# #Epoch 276: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 277: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 278: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 279: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 280: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 281: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 282: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 283: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 284: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 285: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 286: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 287: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 288: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1012
# #Epoch 289: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 290: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 291: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 292: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 293: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 294: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 295: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 296: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 297: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 298: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 299: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 300: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# Switching to learning rate 0.000100
# #Epoch 301: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 302: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 303: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 304: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 305: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 306: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 307: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 308: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 309: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 310: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 311: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 312: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 313: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 314: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 315: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 316: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 317: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 318: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 319: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 320: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 321: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 322: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 323: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 324: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 325: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 326: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 327: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 328: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 329: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 330: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 331: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 332: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 333: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 334: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 335: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 336: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 337: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 338: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 339: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 340: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 341: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 342: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 343: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 344: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 345: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 346: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 347: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 348: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 349: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 350: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 351: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 352: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 353: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 354: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 355: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 356: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 357: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 358: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 359: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 360: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 361: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 362: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 363: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 364: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 365: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 366: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 367: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 368: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 369: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 370: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 371: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 372: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 373: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 374: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 375: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 376: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 377: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 378: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 379: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 380: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 381: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 382: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 383: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 384: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 385: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 386: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 387: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1011
# #Epoch 388: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 389: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 390: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 391: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 392: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 393: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 394: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 395: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 396: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 397: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 398: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 399: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 400: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# Switching to learning rate 0.000010
# #Epoch 401: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 402: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 403: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 404: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 405: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 406: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 407: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 408: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 409: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 410: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 411: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 412: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 413: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 414: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 415: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 416: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 417: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 418: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 419: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 420: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 421: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 422: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 423: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 424: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 425: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 426: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 427: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 428: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 429: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 430: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 431: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 432: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 433: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 434: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 435: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 436: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 437: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 438: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 439: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 440: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 441: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 442: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 443: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 444: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 445: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 446: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 447: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 448: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 449: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 450: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 451: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 452: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 453: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 454: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 455: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 456: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 457: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 458: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 459: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 460: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 461: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 462: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 463: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 464: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 465: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 466: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 467: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 468: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 469: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 470: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 471: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 472: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 473: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 474: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 475: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 476: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 477: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 478: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 479: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 480: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 481: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 482: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 483: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 484: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 485: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 486: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 487: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 488: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 489: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 490: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 491: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 492: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 493: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 494: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 495: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 496: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 497: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 498: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 499: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
# #Epoch 500: Reconstruct Loss: 0.0755, Valid Reconstruct Loss: 0.1010
